# %% [markdown]
# # H3K4Me3 occupancy in immune cells via ChIP-seq

# %% [markdown]
# First, load file metadata and dependencies. Note that rows in the metadata are already aligned to be from the same observation.

# %%
import sys
sys.path.append("./")
import pandas as pd
import numpy as np
from settings import settings, paths
import os
import muffin
import scanpy as sc

metadata_chip = pd.read_csv(paths.immuneChipPath + "metadata_mod.tsv", sep="\t")
# List of paths to all files
bam_files = [paths.immuneChipPath + "chip/" + f + ".bam" for f in metadata_chip.loc[:, "ChIP"]]
input_files = [paths.immuneChipPath + "input/" + f + ".bam" for f in metadata_chip.loc[:, "Inputs"]]
peak_files = [paths.immuneChipPath + "peaks/" + f + ".bigBed" for f in metadata_chip.loc[:, "Peaks"]]

# %% [markdown]
# Now, we load the bed files for each experiment. Here they were in bigBed format so that takes a bit more code.

# %%
import pyBigWig
def read_bigBed_encode(path):
    bb = pyBigWig.open(path)
    chroms = bb.chroms()
    entries_list = []
    for chrom, length in chroms.items():
        entries = bb.entries(chrom, 0, length)
        for entry in entries:
            entries_list.append({
                'chrom': chrom,
                'start': int(entry[0]),
                'end': int(entry[1]),
                'name': entry[2],
            })
    df = pd.DataFrame(entries_list)
    df[["name", "Score", "Strand", "FC", "Pval", "FDR", "Summit"]] = df["name"].str.split("\t", expand=True)
    df[["FC", "Pval", "FDR"]] = df[["FC", "Pval", "FDR"]].astype("float")
    df["Summit"] = df["Summit"].astype(int)
    return df
beds = [read_bigBed_encode(f) for f in peak_files]
# Not necessary
concat_bed = pd.concat(beds)
concat_bed.to_csv("h3k4me3_results/all_beds.bed",sep="\t",header=None,index=None)

# %% [markdown]
# Next, we will identify consensus peaks which merges similar peaks across experiments.

# %%
chromSizes = pd.read_csv(paths.chromsizes, sep="\t", header=None, index_col=0).iloc[:,0].to_dict()
consensus_peaks = muffin.merge_peaks(beds, chromSizes)
consensus_peaks.to_csv("h3k4me3_results/consensus_peaks.bed",sep="\t",header=None,index=None)
# Not needed anymore
del beds

# %% [markdown]
# Now that we have our genomic regions of interest, we can sample the sequencing signal in BAM files and generate the count matrix. Note that you can provide custom parameters for featureCounts here. Alternatively, instead of providing a dataframe for the query regions, you can provide a path to a bed or SAF file through the genomic_regions_path argument.

# %%
featureCountParams = {"nthreads":16, "allowMultiOverlap":True, "minOverlap":-100,
                      "countMultiMappingReads":False}
dataset = muffin.load.dataset_from_bam(bam_files, genomic_regions=consensus_peaks,
                                       input_bam_paths=input_files, 
                                       featureCounts_params=featureCountParams,chromsizes=chromSizes)
# Out:
# Directory tmp_muffin/ already exists !
#
#         ==========     _____ _    _ ____  _____  ______          _____
#         =====         / ____| |  | |  _ \|  __ \|  ____|   /\   |  __ \
#           =====      | (___ | |  | | |_) | |__) | |__     /  \  | |  | |
#             ====      \___ \| |  | |  _ <|  _  /|  __|   / /\ \ | |  | |
#               ====    ____) | |__| | |_) | | \ \| |____ / ____ \| |__| |
#         ==========   |_____/ \____/|____/|_|  \_\______/_/    \_\_____/
#        Rsubread 2.8.2
#
# //========================== featureCounts setting ===========================\\
# ||                                                                            ||
# ||             Input files : 52 BAM files                                     ||
# ||                                                                            ||
# ||                           ENCFF499NSJ.bam                                  ||
# ||                           ENCFF006DTI.bam                                  ||
# ||                           ENCFF569BNQ.bam                                  ||
# ||                           ENCFF642LZZ.bam                                  ||
# ||                           ENCFF135PWQ.bam                                  ||
# ||                           ENCFF208VCM.bam                                  ||
# ||                           ENCFF234GSL.bam                                  ||
# ||                           ENCFF213VRU.bam                                  ||
# ||                           ENCFF661HCG.bam                                  ||
# ||                           ENCFF365AYG.bam                                  ||
# ||                           ENCFF558XUB.bam                                  ||
# ||                           ENCFF126SQQ.bam                                  ||
# ||                           ENCFF660SOQ.bam                                  ||
# ||                           ENCFF489WEK.bam                                  ||
# ||                           ENCFF316MYK.bam                                  ||
# ||                           ENCFF131QPU.bam                                  ||
# ||                           ENCFF087KRI.bam                                  ||
# ||                           ENCFF587PBV.bam                                  ||
# ||                           ENCFF792VGT.bam                                  ||
# ||                           ENCFF728LMW.bam                                  ||
# ||                           ENCFF537JAK.bam                                  ||
# ||                           ENCFF108MOM.bam                                  ||
# ||                           ENCFF449WLP.bam                                  ||
# ||                           ENCFF931ZKM.bam                                  ||
# ||                           ENCFF281BPR.bam                                  ||
# ||                           ENCFF347FAA.bam                                  ||
# ||                           ENCFF470HCZ.bam                                  ||
# ||                           ENCFF850YUJ.bam                                  ||
# ||                           ENCFF333HJE.bam                                  ||
# ||                           ENCFF432RVZ.bam                                  ||
# ||                           ENCFF769NQJ.bam                                  ||
# ||                           ENCFF530KNQ.bam                                  ||
# ||                           ENCFF583WYG.bam                                  ||
# ||                           ENCFF325VPA.bam                                  ||
# ||                           ENCFF736WZO.bam                                  ||
# ||                           ENCFF944ILJ.bam                                  ||
# ||                           ENCFF758IRK.bam                                  ||
# ||                           ENCFF783BBS.bam                                  ||
# ||                           ENCFF480QOG.bam                                  ||
# ||                           ENCFF942NWX.bam                                  ||
# ||                           ENCFF586CJX.bam                                  ||
# ||                           ENCFF161YAG.bam                                  ||
# ||                           ENCFF742RXJ.bam                                  ||
# ||                           ENCFF913INP.bam                                  ||
# ||                           ENCFF834KKV.bam                                  ||
# ||                           ENCFF703QBX.bam                                  ||
# ||                           ENCFF419JPV.bam                                  ||
# ||                           ENCFF545ZER.bam                                  ||
# ||                           ENCFF226WZE.bam                                  ||
# ||                           ENCFF014MGB.bam                                  ||
# ||                           ENCFF144PKE.bam                                  ||
# ||                           ENCFF640GCK.bam                                  ||
# ||                                                                            ||
# ||              Paired-end : no                                               ||
# ||        Count read pairs : no                                               ||
# ||              Annotation : ann.saf (SAF)                                    ||
# ||      Dir for temp files : .                                                ||
# ||                 Threads : 16                                               ||
# ||                   Level : meta-feature level                               ||
# ||      Multimapping reads : not counted                                      ||
# || Multi-overlapping reads : counted                                          ||
# ||   Min overlapping bases : 1                                                ||
# ||          Read extension : 101 on 5' and 101 on 3' ends                     ||
# ||                                                                            ||
# \\============================================================================//
#
# //================================= Running ==================================\\
# ||                                                                            ||
# || Load annotation file ann.saf ...                                           ||
# ||    Features : 173624                                                       ||
# ||    Meta-features : 173624                                                  ||
# ||    Chromosomes/contigs : 180                                               ||
# ||                                                                            ||
# || Process BAM file ENCFF499NSJ.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 13469696                                             ||
# ||    Successfully assigned alignments : 3028641 (22.5%)                      ||
# ||    Running time : 0.03 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF006DTI.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 34003589                                             ||
# ||    Successfully assigned alignments : 8334888 (24.5%)                      ||
# ||    Running time : 0.06 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF569BNQ.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 23084930                                             ||
# ||    Successfully assigned alignments : 8374191 (36.3%)                      ||
# ||    Running time : 0.04 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF642LZZ.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 20591430                                             ||
# ||    Successfully assigned alignments : 10127476 (49.2%)                     ||
# ||    Running time : 0.03 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF135PWQ.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 20145469                                             ||
# ||    Successfully assigned alignments : 10409062 (51.7%)                     ||
# ||    Running time : 0.03 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF208VCM.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 21502380                                             ||
# ||    Successfully assigned alignments : 8802220 (40.9%)                      ||
# ||    Running time : 0.04 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF234GSL.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 30287675                                             ||
# ||    Successfully assigned alignments : 17802922 (58.8%)                     ||
# ||    Running time : 0.05 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF213VRU.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 24648172                                             ||
# ||    Successfully assigned alignments : 9144827 (37.1%)                      ||
# ||    Running time : 0.04 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF661HCG.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 28746534                                             ||
# ||    Successfully assigned alignments : 13258126 (46.1%)                     ||
# ||    Running time : 0.05 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF365AYG.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 11345830                                             ||
# ||    Successfully assigned alignments : 825611 (7.3%)                        ||
# ||    Running time : 0.02 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF558XUB.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 17863571                                             ||
# ||    Successfully assigned alignments : 4271200 (23.9%)                      ||
# ||    Running time : 0.03 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF126SQQ.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 18078868                                             ||
# ||    Successfully assigned alignments : 5029389 (27.8%)                      ||
# ||    Running time : 0.04 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF660SOQ.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 21396665                                             ||
# ||    Successfully assigned alignments : 6594204 (30.8%)                      ||
# ||    Running time : 0.04 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF489WEK.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 12569784                                             ||
# ||    Successfully assigned alignments : 3003545 (23.9%)                      ||
# ||    Running time : 0.02 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF316MYK.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 23421220                                             ||
# ||    Successfully assigned alignments : 7198354 (30.7%)                      ||
# ||    Running time : 0.04 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF131QPU.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 13266911                                             ||
# ||    Successfully assigned alignments : 5997430 (45.2%)                      ||
# ||    Running time : 0.02 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF087KRI.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 28926967                                             ||
# ||    Successfully assigned alignments : 5329805 (18.4%)                      ||
# ||    Running time : 0.04 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF587PBV.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 30573215                                             ||
# ||    Successfully assigned alignments : 5393735 (17.6%)                      ||
# ||    Running time : 0.04 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF792VGT.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 5285100                                              ||
# ||    Successfully assigned alignments : 1163198 (22.0%)                      ||
# ||    Running time : 0.03 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF728LMW.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 27387086                                             ||
# ||    Successfully assigned alignments : 3587862 (13.1%)                      ||
# ||    Running time : 0.05 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF537JAK.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 20464736                                             ||
# ||    Successfully assigned alignments : 5288762 (25.8%)                      ||
# ||    Running time : 0.04 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF108MOM.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 13870058                                             ||
# ||    Successfully assigned alignments : 2647497 (19.1%)                      ||
# ||    Running time : 0.03 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF449WLP.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 9211562                                              ||
# ||    Successfully assigned alignments : 3591318 (39.0%)                      ||
# ||    Running time : 0.02 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF931ZKM.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 8098538                                              ||
# ||    Successfully assigned alignments : 5523489 (68.2%)                      ||
# ||    Running time : 0.02 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF281BPR.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 9539411                                              ||
# ||    Successfully assigned alignments : 6317684 (66.2%)                      ||
# ||    Running time : 0.03 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF347FAA.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 26161252                                             ||
# ||    Successfully assigned alignments : 19167873 (73.3%)                     ||
# ||    Running time : 0.05 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF470HCZ.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 19611876                                             ||
# ||    Successfully assigned alignments : 2725837 (13.9%)                      ||
# ||    Running time : 0.03 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF850YUJ.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 18704639                                             ||
# ||    Successfully assigned alignments : 5347669 (28.6%)                      ||
# ||    Running time : 0.03 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF333HJE.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 13539143                                             ||
# ||    Successfully assigned alignments : 3653558 (27.0%)                      ||
# ||    Running time : 0.02 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF432RVZ.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 17435624                                             ||
# ||    Successfully assigned alignments : 9185087 (52.7%)                      ||
# ||    Running time : 0.03 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF769NQJ.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 5420267                                              ||
# ||    Successfully assigned alignments : 2980915 (55.0%)                      ||
# ||    Running time : 0.01 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF530KNQ.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 8979072                                              ||
# ||    Successfully assigned alignments : 5479927 (61.0%)                      ||
# ||    Running time : 0.02 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF583WYG.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 29097987                                             ||
# ||    Successfully assigned alignments : 14218676 (48.9%)                     ||
# ||    Running time : 0.05 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF325VPA.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 21764999                                             ||
# ||    Successfully assigned alignments : 5775043 (26.5%)                      ||
# ||    Running time : 0.04 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF736WZO.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 15236093                                             ||
# ||    Successfully assigned alignments : 2803653 (18.4%)                      ||
# ||    Running time : 0.03 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF944ILJ.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 24611617                                             ||
# ||    Successfully assigned alignments : 6468510 (26.3%)                      ||
# ||    Running time : 0.04 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF758IRK.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 24585748                                             ||
# ||    Successfully assigned alignments : 4241626 (17.3%)                      ||
# ||    Running time : 0.04 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF783BBS.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 7571935                                              ||
# ||    Successfully assigned alignments : 3619348 (47.8%)                      ||
# ||    Running time : 0.02 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF480QOG.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 7592046                                              ||
# ||    Successfully assigned alignments : 4113476 (54.2%)                      ||
# ||    Running time : 0.02 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF942NWX.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 28915921                                             ||
# ||    Successfully assigned alignments : 6231209 (21.5%)                      ||
# ||    Running time : 0.04 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF586CJX.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 5542512                                              ||
# ||    Successfully assigned alignments : 3041825 (54.9%)                      ||
# ||    Running time : 0.02 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF161YAG.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 23779111                                             ||
# ||    Successfully assigned alignments : 6405160 (26.9%)                      ||
# ||    Running time : 0.04 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF742RXJ.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 11375970                                             ||
# ||    Successfully assigned alignments : 5955148 (52.3%)                      ||
# ||    Running time : 0.02 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF913INP.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 21064526                                             ||
# ||    Successfully assigned alignments : 5526451 (26.2%)                      ||
# ||    Running time : 0.03 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF834KKV.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 23888922                                             ||
# ||    Successfully assigned alignments : 14383885 (60.2%)                     ||
# ||    Running time : 0.04 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF703QBX.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 18477361                                             ||
# ||    Successfully assigned alignments : 12720327 (68.8%)                     ||
# ||    Running time : 0.03 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF419JPV.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 14982866                                             ||
# ||    Successfully assigned alignments : 10076348 (67.3%)                     ||
# ||    Running time : 0.03 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF545ZER.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 22485115                                             ||
# ||    Successfully assigned alignments : 8727269 (38.8%)                      ||
# ||    Running time : 0.04 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF226WZE.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 27196733                                             ||
# ||    Successfully assigned alignments : 5234597 (19.2%)                      ||
# ||    Running time : 0.04 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF014MGB.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 16950298                                             ||
# ||    Successfully assigned alignments : 12223028 (72.1%)                     ||
# ||    Running time : 0.03 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF144PKE.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 39656755                                             ||
# ||    Successfully assigned alignments : 18970011 (47.8%)                     ||
# ||    Running time : 0.06 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF640GCK.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 10999926                                             ||
# ||    Successfully assigned alignments : 6930503 (63.0%)                      ||
# ||    Running time : 0.02 minutes                                             ||
# ||                                                                            ||
# || Write the final count table.                                               ||
# || Write the read assignment summary.                                         ||
# ||                                                                            ||
# \\============================================================================//
#
#
#         ==========     _____ _    _ ____  _____  ______          _____
#         =====         / ____| |  | |  _ \|  __ \|  ____|   /\   |  __ \
#           =====      | (___ | |  | | |_) | |__) | |__     /  \  | |  | |
#             ====      \___ \| |  | |  _ <|  _  /|  __|   / /\ \ | |  | |
#               ====    ____) | |__| | |_) | | \ \| |____ / ____ \| |__| |
#         ==========   |_____/ \____/|____/|_|  \_\______/_/    \_\_____/
#        Rsubread 2.8.2
#
# //========================== featureCounts setting ===========================\\
# ||                                                                            ||
# ||             Input files : 38 BAM files                                     ||
# ||                                                                            ||
# ||                           ENCFF890DSZ.bam                                  ||
# ||                           ENCFF845EVM.bam                                  ||
# ||                           ENCFF749JDM.bam                                  ||
# ||                           ENCFF695GDI.bam                                  ||
# ||                           ENCFF784DGV.bam                                  ||
# ||                           ENCFF140FVH.bam                                  ||
# ||                           ENCFF024UXR.bam                                  ||
# ||                           ENCFF531CAD.bam                                  ||
# ||                           ENCFF748QEI.bam                                  ||
# ||                           ENCFF694UUB.bam                                  ||
# ||                           ENCFF893ADO.bam                                  ||
# ||                           ENCFF126JMA.bam                                  ||
# ||                           ENCFF902FTJ.bam                                  ||
# ||                           ENCFF812BMY.bam                                  ||
# ||                           ENCFF896LUO.bam                                  ||
# ||                           ENCFF513EFO.bam                                  ||
# ||                           ENCFF913MAG.bam                                  ||
# ||                           ENCFF780QBX.bam                                  ||
# ||                           ENCFF382FKE.bam                                  ||
# ||                           ENCFF687ZNJ.bam                                  ||
# ||                           ENCFF198QJK.bam                                  ||
# ||                           ENCFF178GLM.bam                                  ||
# ||                           ENCFF271LTA.bam                                  ||
# ||                           ENCFF539HRS.bam                                  ||
# ||                           ENCFF332TZO.bam                                  ||
# ||                           ENCFF827IPX.bam                                  ||
# ||                           ENCFF061GKY.bam                                  ||
# ||                           ENCFF560NSO.bam                                  ||
# ||                           ENCFF311PTP.bam                                  ||
# ||                           ENCFF134CHO.bam                                  ||
# ||                           ENCFF768JVU.bam                                  ||
# ||                           ENCFF566HDE.bam                                  ||
# ||                           ENCFF671UZW.bam                                  ||
# ||                           ENCFF328STD.bam                                  ||
# ||                           ENCFF075KJA.bam                                  ||
# ||                           ENCFF079UQW.bam                                  ||
# ||                           ENCFF204FWI.bam                                  ||
# ||                           ENCFF804IRE.bam                                  ||
# ||                                                                            ||
# ||              Paired-end : no                                               ||
# ||        Count read pairs : no                                               ||
# ||              Annotation : ann.saf (SAF)                                    ||
# ||      Dir for temp files : .                                                ||
# ||                 Threads : 16                                               ||
# ||                   Level : meta-feature level                               ||
# ||      Multimapping reads : not counted                                      ||
# || Multi-overlapping reads : counted                                          ||
# ||   Min overlapping bases : 1                                                ||
# ||          Read extension : 101 on 5' and 101 on 3' ends                     ||
# ||                                                                            ||
# \\============================================================================//
#
# //================================= Running ==================================\\
# ||                                                                            ||
# || Load annotation file ann.saf ...                                           ||
# ||    Features : 173624                                                       ||
# ||    Meta-features : 173624                                                  ||
# ||    Chromosomes/contigs : 180                                               ||
# ||                                                                            ||
# || Process BAM file ENCFF890DSZ.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 23527984                                             ||
# ||    Successfully assigned alignments : 1314343 (5.6%)                       ||
# ||    Running time : 0.05 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF845EVM.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 57571647                                             ||
# ||    Successfully assigned alignments : 2947299 (5.1%)                       ||
# ||    Running time : 0.08 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF749JDM.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 12830019                                             ||
# ||    Successfully assigned alignments : 752761 (5.9%)                        ||
# ||    Running time : 0.02 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF695GDI.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 26296541                                             ||
# ||    Successfully assigned alignments : 1458999 (5.5%)                       ||
# ||    Running time : 0.04 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF784DGV.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 41930384                                             ||
# ||    Successfully assigned alignments : 2383785 (5.7%)                       ||
# ||    Running time : 0.06 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF140FVH.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 42504697                                             ||
# ||    Successfully assigned alignments : 2431068 (5.7%)                       ||
# ||    Running time : 0.08 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF024UXR.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 22611208                                             ||
# ||    Successfully assigned alignments : 5957454 (26.3%)                      ||
# ||    Running time : 0.04 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF531CAD.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 38797022                                             ||
# ||    Successfully assigned alignments : 2241281 (5.8%)                       ||
# ||    Running time : 0.07 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF748QEI.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 40122074                                             ||
# ||    Successfully assigned alignments : 2285344 (5.7%)                       ||
# ||    Running time : 0.06 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF694UUB.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 27663144                                             ||
# ||    Successfully assigned alignments : 1713822 (6.2%)                       ||
# ||    Running time : 0.04 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF893ADO.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 21989862                                             ||
# ||    Successfully assigned alignments : 1504302 (6.8%)                       ||
# ||    Running time : 0.04 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF126JMA.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 28110168                                             ||
# ||    Successfully assigned alignments : 1352630 (4.8%)                       ||
# ||    Running time : 0.04 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF902FTJ.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 34370868                                             ||
# ||    Successfully assigned alignments : 2094911 (6.1%)                       ||
# ||    Running time : 0.05 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF812BMY.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 36500047                                             ||
# ||    Successfully assigned alignments : 2062322 (5.7%)                       ||
# ||    Running time : 0.07 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF896LUO.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 24502572                                             ||
# ||    Successfully assigned alignments : 1785622 (7.3%)                       ||
# ||    Running time : 0.04 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF513EFO.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 16709215                                             ||
# ||    Successfully assigned alignments : 861420 (5.2%)                        ||
# ||    Running time : 0.03 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF913MAG.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 40897614                                             ||
# ||    Successfully assigned alignments : 2893887 (7.1%)                       ||
# ||    Running time : 0.07 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF780QBX.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 27133664                                             ||
# ||    Successfully assigned alignments : 1425160 (5.3%)                       ||
# ||    Running time : 0.05 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF382FKE.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 33247468                                             ||
# ||    Successfully assigned alignments : 1528088 (4.6%)                       ||
# ||    Running time : 0.05 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF687ZNJ.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 28895736                                             ||
# ||    Successfully assigned alignments : 1659187 (5.7%)                       ||
# ||    Running time : 0.07 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF198QJK.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 29198392                                             ||
# ||    Successfully assigned alignments : 1716551 (5.9%)                       ||
# ||    Running time : 0.05 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF178GLM.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 31295183                                             ||
# ||    Successfully assigned alignments : 1760353 (5.6%)                       ||
# ||    Running time : 0.05 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF271LTA.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 39713757                                             ||
# ||    Successfully assigned alignments : 2200925 (5.5%)                       ||
# ||    Running time : 0.06 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF539HRS.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 22595975                                             ||
# ||    Successfully assigned alignments : 1145582 (5.1%)                       ||
# ||    Running time : 0.04 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF332TZO.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 24088705                                             ||
# ||    Successfully assigned alignments : 1644067 (6.8%)                       ||
# ||    Running time : 0.04 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF827IPX.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 20350010                                             ||
# ||    Successfully assigned alignments : 1024097 (5.0%)                       ||
# ||    Running time : 0.03 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF061GKY.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 25173213                                             ||
# ||    Successfully assigned alignments : 1283657 (5.1%)                       ||
# ||    Running time : 0.04 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF560NSO.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 34659158                                             ||
# ||    Successfully assigned alignments : 1982141 (5.7%)                       ||
# ||    Running time : 0.06 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF311PTP.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 37855033                                             ||
# ||    Successfully assigned alignments : 2131960 (5.6%)                       ||
# ||    Running time : 0.06 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF134CHO.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 12995698                                             ||
# ||    Successfully assigned alignments : 1551117 (11.9%)                      ||
# ||    Running time : 0.02 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF768JVU.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 26969726                                             ||
# ||    Successfully assigned alignments : 1747846 (6.5%)                       ||
# ||    Running time : 0.04 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF566HDE.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 35331343                                             ||
# ||    Successfully assigned alignments : 2053735 (5.8%)                       ||
# ||    Running time : 0.05 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF671UZW.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 29111648                                             ||
# ||    Successfully assigned alignments : 1831294 (6.3%)                       ||
# ||    Running time : 0.06 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF328STD.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 20067734                                             ||
# ||    Successfully assigned alignments : 1320187 (6.6%)                       ||
# ||    Running time : 0.03 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF075KJA.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 36489452                                             ||
# ||    Successfully assigned alignments : 2417276 (6.6%)                       ||
# ||    Running time : 0.06 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF079UQW.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 65346108                                             ||
# ||    Successfully assigned alignments : 3566833 (5.5%)                       ||
# ||    Running time : 0.11 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF204FWI.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 46841596                                             ||
# ||    Successfully assigned alignments : 2929716 (6.3%)                       ||
# ||    Running time : 0.08 minutes                                             ||
# ||                                                                            ||
# || Process BAM file ENCFF804IRE.bam...                                        ||
# ||    Single-end reads are included.                                          ||
# ||    Total alignments : 36700756                                             ||
# ||    Successfully assigned alignments : 1994174 (5.4%)                       ||
# ||    Running time : 0.06 minutes                                             ||
# ||                                                                            ||
# || Write the final count table.                                               ||
# || Write the read assignment summary.                                         ||
# ||                                                                            ||
# \\============================================================================//

# %% [markdown]
# The dataset is in an anndata object, which allows for an easy annotation of the count matrix, and the storage of different count transforms.

# %%
print(dataset)
# Out:
# AnnData object with n_obs × n_vars = 52 × 163624
#     var: 'Chromosome', 'Start', 'End', 'Strand'
#     uns: 'counts_random', 'tot_mapped_counts', 'input_random'
#     layers: 'input'

# %% [markdown]
# You can set plot settings for muffin :

# %%
muffin.params["autosave_plots"] = "h3k4me3_results/"
muffin.params["figure_dpi"] = 300
muffin.params["autosave_format"] = ".pdf"
sc.set_figure_params(dpi=300, dpi_save=300)
sc.settings.autosave = True
sc.settings.figdir = "h3k4me3_results/"
# Makes pdf font editable with pdf editors
import matplotlib as mpl
mpl.rcParams['pdf.fonttype'] = 42

# %% [markdown]
# Here, we can re-name our features (columns of the count matrix) to the nearest gene's name for convenience in downstream analyses. The dataset variable annotation has been automatically annotated with genomic locations in the previous step. Note that the gsea_obj object also provides functions for gene set enrichment of nearby genes.

# %%
gsea_obj = muffin.grea.pyGREAT(paths.GOfile, paths.gencode, paths.chromsizes)
dataset.var_names = gsea_obj.label_by_nearest_gene(dataset.var[["Chromosome","Start","End"]]).astype(str)

# %% [markdown]
# Here, we set up the design matrix of the linear model. If you do not want to regress any confounding factors leave it to a column array of ones as in the example. Note that it can have a tendency to "over-regress" and remove biological signal as it is a simple linear correction.

# %% [markdown]
# Now, we are count to normalize the input counts using our centering and scaling approach. Alternatively, you can use the rescale_input_quantile function. We are also going to remove features with very low signal (note that this step is mandatory to remove fully zero counts, which will cause numerical issues later on when fitting NB models).

# %%
print(dataset)
dataset = dataset.copy()
muffin.tools.rescale_input_center_scale(dataset, plot=True)
design = np.concatenate([np.ones((len(dataset),1))], axis=1)
print(design.shape)
muffin.load.set_design_matrix(dataset, design)
detectable = muffin.tools.trim_low_counts(dataset)
dataset = dataset[:, detectable]
print(dataset.obs["pi0"])
# Out:
# AnnData object with n_obs × n_vars = 52 × 163624
#     var: 'Chromosome', 'Start', 'End', 'Strand'
#     uns: 'counts_random', 'tot_mapped_counts', 'input_random'
#     layers: 'input'
# (52, 1)
# ENCFF499NSJ.bam     8.106884
# ENCFF006DTI.bam     7.274490
# ENCFF569BNQ.bam    10.730376
# ENCFF642LZZ.bam    17.342016
# ENCFF135PWQ.bam    21.784329
# ENCFF208VCM.bam    12.230853
# ENCFF234GSL.bam    26.268808
# ENCFF213VRU.bam    11.557292
# ENCFF661HCG.bam    16.243500
# ENCFF365AYG.bam     3.092001
# ENCFF558XUB.bam     7.692400
# ENCFF126SQQ.bam     9.553713
# ENCFF660SOQ.bam     1.787877
# ENCFF489WEK.bam     8.100775
# ENCFF316MYK.bam    10.732399
# ENCFF131QPU.bam    30.012154
# ENCFF087KRI.bam     4.591435
# ENCFF587PBV.bam     4.211772
# ENCFF792VGT.bam    19.928320
# ENCFF728LMW.bam     3.324183
# ENCFF537JAK.bam     7.309610
# ENCFF108MOM.bam     5.041925
# ENCFF449WLP.bam    18.429462
# ENCFF931ZKM.bam    78.326033
# ENCFF281BPR.bam    65.672528
# ENCFF347FAA.bam    61.036927
# ENCFF470HCZ.bam     9.374487
# ENCFF850YUJ.bam    10.745034
# ENCFF333HJE.bam    10.876488
# ENCFF432RVZ.bam    35.405457
# ENCFF769NQJ.bam    60.306345
# ENCFF530KNQ.bam    47.834490
# ENCFF583WYG.bam    19.830932
# ENCFF325VPA.bam     7.094558
# ENCFF736WZO.bam     5.230342
# ENCFF944ILJ.bam     7.060516
# ENCFF758IRK.bam     4.300845
# ENCFF783BBS.bam    29.054757
# ENCFF480QOG.bam    37.557687
# ENCFF942NWX.bam     6.151919
# ENCFF586CJX.bam    49.785625
# ENCFF161YAG.bam     8.218014
# ENCFF742RXJ.bam    27.656365
# ENCFF913INP.bam     8.349627
# ENCFF834KKV.bam    37.094743
# ENCFF703QBX.bam    50.445713
# ENCFF419JPV.bam    53.346162
# ENCFF545ZER.bam    15.995437
# ENCFF226WZE.bam     5.561307
# ENCFF014MGB.bam    27.030616
# ENCFF144PKE.bam    17.523685
# ENCFF640GCK.bam    45.904641
# Name: pi0, dtype: float64

# %% [markdown]
# The next step is to fit the mean-variance relationship and the compute residuals to the fitted Negative Binomial model.

# %%
muffin.tools.compute_residuals(dataset, maxThreads=16)
# Out:
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done 248 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=16)]: Done 2000 out of 2000 | elapsed:  1.0min finished
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done 9248 tasks      | elapsed:   22.2s
# [Parallel(n_jobs=16)]: Done 86048 tasks      | elapsed:   55.0s
# [Parallel(n_jobs=16)]: Done 161266 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=16)]: Done 163624 out of 163624 | elapsed:  1.4min finished
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# AnnData object with n_obs × n_vars = 52 × 163624
#     obs: 'size_factors', 'size_factors_input', 'centered_lfc', 'pi0'
#     var: 'Chromosome', 'Start', 'End', 'Strand', 'means', 'variances', 'reg_alpha'
#     uns: 'counts_random', 'tot_mapped_counts', 'input_random'
#     obsm: 'design'
#     layers: 'input', 'normalization_factors', 'residuals'

# %% [markdown]
# We can perform feature selection to remove peaks with low information. Additionally for ChIP-seq we propose a tool to remove features with insufficient enrichment over input, which can be useful if you use a large catalogue of regions without peak calling. As peak calling was already performed, almost all features are passing this step.

# %%
peaks = muffin.tools.pseudo_peak_calling(dataset)
hv = muffin.tools.feature_selection_elbow(dataset)
print(np.mean(peaks))
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# 0.9999938884271256

# %% [markdown]
# Next, we perform dimensionnality reduction through with PCA and UMAP.

# %%
muffin.tools.compute_pa_pca(dataset, feature_mask=peaks&hv, plot=True)
muffin.tools.compute_umap(dataset)
# Out:
# AnnData object with n_obs × n_vars = 52 × 163624
#     obs: 'size_factors', 'size_factors_input', 'centered_lfc', 'pi0'
#     var: 'Chromosome', 'Start', 'End', 'Strand', 'means', 'variances', 'reg_alpha'
#     uns: 'counts_random', 'tot_mapped_counts', 'input_random', 'pca'
#     obsm: 'design', 'X_pca', 'X_umap'
#     varm: 'PCs'
#     layers: 'input', 'normalization_factors', 'residuals'

# %% [markdown]
# Display the results. Note that we can use scanpy functions here!

# %%
# Append cell type info to the dataset
dataset.obs["Cell type detailed"] = metadata_chip["Biosample term name"].values
dataset.obs["Cell type"] = metadata_chip["Biosample cell type"].values
sc.pl.umap(dataset, color='Cell type', legend_loc='on data',
                legend_fontsize=4, legend_fontoutline=0.1, s=15.0,
                palette='Paired')
sc.pl.pca(dataset, color='Cell type', legend_loc='on data',
                legend_fontsize=4, legend_fontoutline=0.1, s=15.0,
                palette='Paired')
# Out:
# WARNING: saving figure to file h3k4me3_results/umap.pdf
# WARNING: saving figure to file h3k4me3_results/pca.pdf

# %% [markdown]
# We can also use heatmaps, even if we have a large number of features :

# %%
print((peaks & hv).sum())
fig, ax = muffin.plots.mega_heatmap(dataset[:, peaks & hv], layer="residuals", label_col="Cell type", vmin=-3, vmax=3)
# Out:
# 46144

# %% [markdown]
# Let's find the differentially bound regions between T-cells and B-cells:

# %%
# First subset our dataset
selected = dataset[(dataset.obs["Cell type"] == "B cell") | (dataset.obs["Cell type"] == "T cell")]
muffin.tools.differential_expression_A_vs_B(selected, category="Cell type", 
                                        ref_category="T cell")
# Out:
# Comparing B cell to (reference) T cell
# Using DESeq2 with normalization factors per row, per gene
# R[write to console]: converting counts to integer mode
#
# R[write to console]: using pre-existing normalization factors
#
# R[write to console]: estimating dispersions
#
# R[write to console]: gene-wise dispersion estimates
#
# R[write to console]: mean-dispersion relationship
#
# R[write to console]: final dispersion estimates
#
# R[write to console]: fitting model and testing
#
# R[write to console]: -- replacing outliers and refitting for 1442 genes
# -- DESeq argument 'minReplicatesForReplace' = 7
# -- original counts are preserved in counts(dds)
#
# R[write to console]: estimating dispersions
#
# R[write to console]: fitting model and testing
#
# R[write to console]: using 'apeglm' for LFC shrinkage. If used in published research, please cite:
#     Zhu, A., Ibrahim, J.G., Love, M.I. (2018) Heavy-tailed prior distributions for
#     sequence count data: removing the noise and preserving large differences.
#     Bioinformatics. https://doi.org/10.1093/bioinformatics/bty895

# %% [markdown]
# Let's have a first look at the best markers between B and T cells :

# %%
sc.pl.rank_genes_groups_heatmap(selected,layer="residuals", 
                                use_raw=False, vmin=-3, vmax=3, 
                                cmap='viridis')
selected.varm["DE_results"].sort_values("padj")
# Out:
# WARNING: dendrogram data not found (using key=dendrogram_Cell type). Running `sc.tl.dendrogram` with default parameters. For fine tuning it is recommended to run `sc.tl.dendrogram` independently.
# WARNING: saving figure to file h3k4me3_results/heatmap.pdf
#                    z-score  log2FoldChange        pvalue          padj
# HLA-DOB_7        15.302674        5.088282  7.337924e-53  1.100769e-47
# CYB561A3_4       14.518801        4.745618  9.210675e-48  6.908513e-43
# CTD-2545M3.6_1   14.475394        4.847525  1.733287e-47  8.667071e-43
# MIR4537_5        14.221296        5.427724  6.758923e-46  2.027826e-41
# RP11-380I10.4_3  14.234765        4.651491  5.575039e-46  2.027826e-41
# ...                    ...             ...           ...           ...
# GLYATL1_3        -0.062054       -0.023450  9.505201e-01  1.000000e+00
# GLYATL2_4         0.011781        0.023025  9.906005e-01  1.000000e+00
# GLYATL2_3         0.811865        0.319651  4.168689e-01  1.000000e+00
# GLYATL2_2         0.145809        0.052990  8.840719e-01  1.000000e+00
# DDX11L1_1         0.255995        0.156249  7.979547e-01  1.000000e+00
#
# [163624 rows x 4 columns]

# %% [markdown]
# We can already see genes specific to T cells (CD3E, CD3D...) and some specific to B cells (BLNK, BLK...). We can go further and perform a Genomic Regions Enrichment Analysis to get a GSEA of nearby genes.

# %%
# Retrieve DE regions
DE_indexes = (selected.varm["DE_results"]["padj"] < 0.05) & (np.abs(selected.varm["DE_results"]["log2FoldChange"]) > 1.0)
all_regions = selected.var[["Chromosome", "Start", "End"]]
query = all_regions[DE_indexes]
# Perform GREA
gsea_results = gsea_obj.find_enriched(query, all_regions, cores=16)
gsea_results
# Out:
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done 2624 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=16)]: Done 8504 tasks      | elapsed:  5.4min
# [Parallel(n_jobs=16)]: Done 9170 out of 9170 | elapsed:  5.9min finished
#              P(Beta > 0)      Beta  BH corrected p-value  -log10(qval)  \
# 0
# GO:0002250  2.345892e-48  0.585885          2.151183e-44  4.366732e+01
# GO:0046649  5.110348e-17  0.288325          2.343095e-13  1.263021e+01
# GO:0002684  7.162489e-16  0.254110          1.978139e-12  1.170374e+01
# GO:0050851  8.628743e-16  0.521975          1.978139e-12  1.170374e+01
# GO:0045321  1.152480e-15  0.254527          2.113649e-12  1.167497e+01
# ...                  ...       ...                   ...           ...
# GO:0019752  9.999925e-01 -0.177232          9.999999e-01  3.190078e-08
# GO:0007098  9.999960e-01 -0.515354          9.999999e-01  3.190078e-08
# GO:0007017  9.999976e-01 -0.185194          9.999999e-01  3.190078e-08
# GO:0000226  9.999987e-01 -0.231113          9.999999e-01  3.190078e-08
# GO:0070925  9.999999e-01 -0.207059          9.999999e-01  3.190078e-08
#
#             -log10(pval)        FC  \
# 0
# GO:0002250  4.762969e+01  1.796580
# GO:0046649  1.629155e+01  1.334190
# GO:0002684  1.514494e+01  1.289313
# GO:0050851  1.506405e+01  1.685352
# GO:0045321  1.493837e+01  1.289851
# ...                  ...       ...
# GO:0019752  3.263525e-06  0.837586
# GO:0007098  1.726051e-06  0.597289
# GO:0007017  1.023852e-06  0.830943
# GO:0000226  5.451083e-07  0.793650
# GO:0070925  3.190078e-08  0.812972
#
#                                                     Name  Total hits
# 0
# GO:0002250                      adaptive immune response        2939
# GO:0046649                         lymphocyte activation        4061
# GO:0002684  positive regulation of immune system process        4251
# GO:0050851   antigen receptor-mediated signaling pathway        1382
# GO:0045321                          leukocyte activation        4509
# ...                                                  ...         ...
# GO:0019752             carboxylic acid metabolic process        1404
# GO:0007098                              centrosome cycle         130
# GO:0007017                     microtubule-based process        1338
# GO:0000226         microtubule cytoskeleton organization         879
# GO:0070925                            organelle assembly        1483
#
# [9170 rows x 8 columns]

# %% [markdown]
# We do observe an enrichment of immune and T/B Cells related terms.

# %%
import plotly.offline as pyo
gsea_obj.cluster_treemap(gsea_results)
# Out:
# <div>                            <div id="e527739a-dbe0-4fb0-a1db-78ec95a94ccd" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e527739a-dbe0-4fb0-a1db-78ec95a94ccd")) {                    Plotly.newPlot(                        "e527739a-dbe0-4fb0-a1db-78ec95a94ccd",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}<br>value=%{value}<br>parent=%{parent}<extra></extra>","labels":["Lymphocyte<br>activation","Leukocyte<br>activation","Positive<br>regulation of<br>leukocyte<br>activation","Positive<br>regulation of<br>cell activation","Positive<br>regulation of<br>lymphocyte<br>activation","B cell<br>activation","Lymphocyte<br>proliferation","Mononuclear<br>cell<br>proliferation","Leukocyte<br>proliferation","T cell<br>activation","Lymphocyte<br>differentiation","Mononuclear<br>cell<br>differentiation","Leukocyte<br>differentiation","Alpha-beta t<br>cell activation","T cell<br>differentiation","Lymphocyte<br>activation<br>involved in<br>immune response","Hemopoiesis","Leukocyte<br>activation<br>involved in<br>immune response","Regulation of t<br>cell activation","Positive<br>regulation of t<br>cell activation","Positive<br>regulation of<br>leukocyte cell-<br>cell adhesion","Leukocyte cell-<br>cell adhesion","Regulation of<br>leukocyte cell-<br>cell adhesion","Positive<br>regulation of<br>cell-cell<br>adhesion","Regulation of<br>cell-cell<br>adhesion","Positive<br>regulation of<br>cell adhesion","Positive<br>regulation of t<br>cell<br>differentiation","Adaptive immune<br>response","Immune effector<br>process","Lymphocyte<br>mediated<br>immunity","Adaptive immune<br>response based<br>on somatic<br>recombination<br>of immune<br>receptors built<br>from<br>immunoglobulin<br>superfamily<br>domains","Leukocyte<br>mediated<br>immunity","Regulation of<br>immune effector<br>process","Regulation of<br>lymphocyte<br>mediated<br>immunity","Regulation of<br>leukocyte<br>mediated<br>immunity","Positive<br>regulation of<br>immune effector<br>process","Positive<br>regulation of<br>immune system<br>process","Antigen<br>receptor-<br>mediated<br>signaling<br>pathway","Immune<br>response-<br>activating cell<br>surface<br>receptor<br>signaling<br>pathway","Positive<br>regulation of<br>immune response","Immune<br>response-<br>regulating cell<br>surface<br>receptor<br>signaling<br>pathway","Regulation of<br>immune response","Immune<br>response-<br>activating<br>signaling<br>pathway","Immune<br>response-<br>regulating<br>signaling<br>pathway","Activation of<br>immune response","Regulation of<br>type ii<br>interferon<br>production","Type ii<br>interferon<br>production","Interleukin-4<br>production","Regulation of<br>interleukin-4<br>production","Positive<br>regulation of<br>type ii<br>interferon<br>production","Cytokine<br>production","Positive<br>regulation of<br>interleukin-4<br>production","Response to<br>bacterium","Regulation of<br>cytokine<br>production","Regulation of<br>lymphocyte<br>activation","Regulation of<br>cell activation","Regulation of<br>leukocyte<br>activation","Negative<br>regulation of<br>immune system<br>process","Negative<br>regulation of<br>leukocyte<br>activation","Negative<br>regulation of<br>cell activation","Negative<br>regulation of<br>immune response","Negative<br>regulation of t<br>cell activation","Negative<br>regulation of<br>lymphocyte<br>activation","Lymphocyte<br>apoptotic<br>process","Leukocyte<br>apoptotic<br>process","Regulation of<br>lymphocyte<br>apoptotic<br>process","Regulation of<br>leukocyte<br>apoptotic<br>process","Lymphocyte<br>homeostasis","Leukocyte<br>homeostasis","Negative<br>regulation of<br>leukocyte<br>apoptotic<br>process","B cell<br>homeostasis","Negative<br>regulation of<br>lymphocyte<br>apoptotic<br>process","Regulati ...
#              P(Beta > 0)      Beta  BH corrected p-value  -log10(qval)  \
# 0
# GO:0046649  5.110348e-17  0.288325          2.343095e-13     12.630210
# GO:0045321  1.152480e-15  0.254527          2.113649e-12     11.674967
# GO:0002696  5.522070e-13  0.344569          4.603399e-10      9.336921
# GO:0050867  6.506131e-13  0.338011          4.954420e-10      9.305007
# GO:0051251  7.074394e-13  0.362142          4.954420e-10      9.305007
# ...                  ...       ...                   ...           ...
# GO:0002312  8.631356e-05  0.377115          7.195412e-03      2.142944
# GO:0002520  1.968684e-04  0.236931          1.399444e-02      1.854044
# GO:0002200  2.681538e-04  0.366380          1.769043e-02      1.752262
# GO:0016444  2.940887e-04  0.380725          1.872773e-02      1.727515
# GO:0002562  2.940887e-04  0.380725          1.872773e-02      1.727515
#
#             -log10(pval)        FC  \
# 0
# GO:0046649     16.291549  1.334190
# GO:0045321     14.938367  1.289851
# GO:0002696     12.257898  1.411381
# GO:0050867     12.186677  1.402156
# GO:0051251     12.150311  1.436403
# ...                  ...       ...
# GO:0002312      4.063921  1.458072
# GO:0002520      3.705824  1.267354
# GO:0002200      3.571616  1.442503
# GO:0016444      3.531522  1.463346
# GO:0002562      3.531522  1.463346
#
#                                                          Name  Total hits  \
# 0
# GO:0046649                           Lymphocyte<br>activation        4061
# GO:0045321                            Leukocyte<br>activation        4509
# GO:0002696  Positive<br>regulation of<br>leukocyte<br>acti...        2096
# GO:0050867       Positive<br>regulation of<br>cell activation        2128
# GO:0051251  Positive<br>regulation of<br>lymphocyte<br>act...        1938
# ...                                                       ...         ...
# GO:0002312  B cell<br>activation<br>involved in<br>immune ...         537
# GO:0002520                       Immune system<br>development        1164
# GO:0002200  Somatic<br>diversification<br>of immune<br>rec...         489
# GO:0016444               Somatic cell<br>dna<br>recombination         453
# GO:0002562  Somatic<br>diversification<br>of immune<br>rec...         453
#
#             Cluster               Representative
# 0
# GO:0046649        0
# GO:0045321        0     Lymphocyte<br>activation
# GO:0002696        0     Lymphocyte<br>activation
# GO:0050867        0     Lymphocyte<br>activation
# GO:0051251        0     Lymphocyte<br>activation
# ...             ...                          ...
# GO:0002312        9  B cell mediated<br>immunity
# GO:0002520        9  B cell mediated<br>immunity
# GO:0002200        9  B cell mediated<br>immunity
# GO:0016444        9  B cell mediated<br>immunity
# GO:0002562        9  B cell mediated<br>immunity
#
# [88 rows x 10 columns]

# %% [markdown]
# We can save our work to avoid recomputing everything. It can easily be re-loaded using :  anndata.read_h5ad(path)

# %%
dataset.write("h3k4me3_results/dataset.h5ad")
